# %% [markdown]
# # Flow (tag ✅ if you finished any section)
#
# - General:
#   - Reserved for README
#   - Provide details for any section that you completed
#
# - EDA (data cleaning)
#   - Class 0: Statistics
#     - Sample:
#       - ![Screen%20Shot%202020-03-28%20at%207.53.39%20PM.png](attachment:Screen%20Shot%202020-03-28%20at%207.53.39%20PM.png)
#   - Class 1
#     - Function: Diagonise (ckeck) abnormal texts
#     - Classify those texts into several sub-category
#       - Specific:
#
#   - Class 2
#     - Function: Unify all texts into same standard
#       - Specific
# - FE
#   - N-Gram analysis (class 3)
#     - Unigram
#     - Bigram
#   - Sparse vector representation (class 4)
#     - Tokenzie: Hashing the texts by single/double word
#   - Dense vector representation (?)
#
# - Modeling (class 5)
#   - RNN (LSTM)
#     - Heavy focus: RNN details
#   - CNN (Refer Section 4.9)
#   - Decision tree
#   - Boosting methods (tree + gradient boosting)
#     - Comparision
#     - Stacking (Ensemble)
#
# - Reference
#   - https://github.com/abdulfatir/twitter-sentiment-analysis/blob/master/docs/report.pdf
#   - https://www.kaggle.com/shahules/complete-eda-bert-lstm#Which-are-the-most-common-words?
